# %%
from utils import *

# %%
import utils.dataloaders as dl

# %%
import logging

logging.basicConfig(level=logging.INFO)

# %%
import os
import cv2

# %%
path = '../../datasets/onera/'

# %%
cities = [i for i in os.listdir(path + 'images/') if not i.startswith('.') and os.path.isdir(path+'images/'+i)]

# %%
cities
# Out:
# ['paris',
#  'mumbai',
#  'valencia',
#  'aguasclaras',
#  'milano',
#  'abudhabi',
#  'nantes',
#  'montpellier',
#  'rennes',
#  'chongqing',
#  'rio',
#  'bercy',
#  'bordeaux',
#  'hongkong',
#  'pisa',
#  'norcia',
#  'saclay_e',
#  'beirut',
#  'dubai',
#  'saclay_w',
#  'beihai',
#  'brasilia',
#  'lasvegas',
#  'cupertino']

# %%
# dl.full_onera_loader('../../datasets/onera/', load_label=True, load_mask=True)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/anaconda3/envs/granular/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/anaconda3/envs/granular/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/sid/Desktop/internal_tools/polyExperiments/changeDetection/utils/dataloaders.py", line 234, in label_loader
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-3c411f547985> in <module>
# ----> 1 dl.full_onera_loader('../../datasets/onera/', load_label=True, load_mask=True)
#
# ...

# %%
cities = os.listdir(path + 'labels/')
label_paths = []
for city in cities:
    if '.txt' not in city:
        label_paths.append(path + 'labels/' + city)

# %%
# from multiprocessing import Pool

# %%
# pool = Pool(26)

# %%
def label_loader(label_path):
    print(label_path)
    if label_path != '../../datasets/onera/labels/valencia':
        label = cv2.imread(label_path + '/cm/' + 'cm.png', 0) / 255
        return label
    else:
        return label_path

# %%
city_labels= []
for i in label_paths:
    label_loader(i)
# Out:
# ../../datasets/onera/labels/paris
# ../../datasets/onera/labels/mumbai
# ../../datasets/onera/labels/aguasclaras
# ../../datasets/onera/labels/abudhabi
# ../../datasets/onera/labels/nantes
# ../../datasets/onera/labels/rennes
# ../../datasets/onera/labels/bercy
# ../../datasets/onera/labels/bordeaux
# ../../datasets/onera/labels/hongkong
# ../../datasets/onera/labels/pisa
# ../../datasets/onera/labels/saclay_e
# ../../datasets/onera/labels/beirut
# ../../datasets/onera/labels/beihai
# ../../datasets/onera/labels/cupertino

# %%
label_paths
# Out:
# ['../../datasets/onera/labels/paris',
#  '../../datasets/onera/labels/mumbai',
#  '../../datasets/onera/labels/.DS_Store',
#  '../../datasets/onera/labels/aguasclaras',
#  '../../datasets/onera/labels/abudhabi',
#  '../../datasets/onera/labels/nantes',
#  '../../datasets/onera/labels/rennes',
#  '../../datasets/onera/labels/bercy',
#  '../../datasets/onera/labels/bordeaux',
#  '../../datasets/onera/labels/hongkong',
#  '../../datasets/onera/labels/pisa',
#  '../../datasets/onera/labels/saclay_e',
#  '../../datasets/onera/labels/beirut',
#  '../../datasets/onera/labels/beihai',
#  '../../datasets/onera/labels/cupertino']
